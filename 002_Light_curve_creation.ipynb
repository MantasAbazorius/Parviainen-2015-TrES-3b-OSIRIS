# %% [markdown]
# # TrES-3b transmission spectroscopy: light curve creation
#
# *<a href="mailto:hannu.parviainen@physics.ox.ac.uk">Hannu Parviainen</a>, University of Oxford*
#
# Here we create the broad- and narrow-band light curves from the reduced spectra, and create a set of plots for the paper.
#
# This notebook is a part in a series of notebooks working as an appendix to Parviainen et al. (2015, submitted), aiming to make the analysis presented in the paper easily reproductable. The results and the figures presented in the paper can be reproduced by following these notebooks in the numbered order.
#
# *Dependencies:* See `000_README.ipynb` for the list of required Python packages, and how to install them.
#
# ## Overview
#
# ### Data
#
# We start with the spectra reduced by G. Nowak stored in directory `data/spectra`. The wavelength solution is calculated in [001_Wavelength_calibration.ipynb](001_Wavelength_calibration.ipynb), and stored as a pickle in `results/wl_calibration.pkl`.
#
#  - The comparison star is on CCD 1
#  - The target star is on CCD 2
#
# ### Filters
#
# The light curves are generated for 16 narrow passbands, defined in `core.py`, and for a broad 'white' passband.  The passbands are defined using a [generalized Gaussian](http://docs.scipy.org/doc/scipy/reference/generated/scipy.signal.general_gaussian.html#scipy.signal.general_gaussian) window function.
# $$
# F(x) = e^{- \frac{1}{2} \left|\frac{x-c}{\sigma}\right|^{2p}}.
# $$
#
# **Spectrum masking:** Some regions of the spectrum (the cores of the telluric absorption bands) were observed to increase the light curve noise level significantly during the initial analysis. We create a set of masked light curves to test whether this has an effect on the parameter estimates (spoiler: yes, it does).
#
# ### Output
#
# The light curves with the auxiliary data are saved as Pandas tables in a HDF5 file `results/light_curves.h5`. The file structure is
#
#  - `/aux`
#  - `/filters`
#  - `/bad_exposures`
#  - `/final/XX_YYYYYY`
#  - `/reference/XX_YYYYYY`
#  - `/target/XX_YYYYYY`
#
# where `XX` is `nb` for narrow-band light curves and `bb` for broadband light curves, and `YYYYYY` is `nomask` for the unmasked LCs and `masked` for the masked LCs.
#
# ### Plots
#
# Finally, the notebook generates plots for the paper Parviainen (2015).

# %% [markdown]
# ## Initialisation

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import warnings
import pyfits as pf
from glob import glob
from pandas import DataFrame as DF
from astropy.time import Time
from scipy.signal import medfilt as mf
from scipy.ndimage import binary_erosion

from core import *

def normalise(lc):
    msk = ones(spectra_2.shape[0], np.bool)
    msk[45:190] = False
    return lc / median(lc[msk])

# %% [markdown]
# ## Import the spectra

# %%
data_dir = 'data/spectra/'
sfiles_1 = sorted(glob(join(data_dir,'*_1.ms.fits')))
sfiles_2 = sorted(glob(join(data_dir,'*_2.ms.fits')))

# %%
spectra_1 = array([pf.getdata(sf, memmap= False ) for sf in sfiles_1]).astype(np.float64)
spectra_2 = array([pf.getdata(sf, memmap= False) for sf in sfiles_2]).astype(np.float64)
# Out:
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000622474995907396 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000869378971401602 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000622417021077126 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000869075010996312 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000869689974933863 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000621968996711075 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000869459006935358 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000622591993305832 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000869767973199487 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000622146006207913 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000869845971465111 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000622991996351629 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000869535026140511 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000622596999164671 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000622235995251685 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000869998999405652 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000622139021288604 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000870616000611335 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000869922980200499 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000623087980784476 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000869233976118267 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000622953986749053 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000870308023877442 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000622291001491249 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000621623999904841 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000869617972057313 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000622561026830226 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000622246996499598 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000870387011673301 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000621984014287591 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000870156974997371 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000622473016846925 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000870155985467136 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000869849987793714 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000623013009317219 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000623412022832781 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000869387004058808 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000622347986791283 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000869198993314058 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000622304971329868 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000869850977323949 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000622576975729316 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000868465984240174 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000869698007591069 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000622847001068294 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000869081995915622 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000622581981588155 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000870005984324962 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000869852025061846 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000622452993411571 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000869083974976093 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000622331979684532 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000869008013978601 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000622276973444968 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000869854004122317 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000622461026068777 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000869547016918659 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000622729014139622 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000868972972966731 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000622509978711605 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000869625015184283 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000869933981448412 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000622741994448006 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000868395029101521 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000622742983978242 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000869165000040084 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000868932984303683 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000868549977894872 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000622796011157334 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000868936011102051 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000868858012836426 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000868473027367145 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000622537976596504 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000622808001935482 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000868629023898393 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000868013012222946 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000622817024122924 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000868475995957851 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000623399973846972 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000623312022071332 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000868705974426121 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000622829014901072 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000868553994223475 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000623676984105259 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000623102008830756 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000868246017489582 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000623017025645822 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000868363014888018 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000868145027197897 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000867996015585959 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000623163999989629 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000868557021021843 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000623076979536563 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000868325005285442 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000623794971033931 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000868173025082797 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000624070991761982 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000868174014613032 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000623760977759957 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000868327973876148 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000623677973635495 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000623858999460936 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000868019997142255 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000868482980877161 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000624225998762995 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000868331000674516 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000623786996584386 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000867790018673986 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000623569008894265 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000867981987539679 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000623974017798901 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000867101014591753 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000623357016593218 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000867257011123002 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000624119013082236 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000867102004121989 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000624168023932725 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000867409980855882 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000867258000653237 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000624311971478164 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000867025984916836 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000624807027634233 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000624635023996234 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000867026974447072 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000625085027422756 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000866797985509038 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000624469015747309 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000866720976773649 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000625141023192555 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000866644026245922 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000624477979727089 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000866413989569992 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000624219013843685 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000624359003268182 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000865723006427288 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000625077984295785 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000865877023898065 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000866018992383033 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000624730018898845 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000866492977365851 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000624471984338015 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000866262998897582 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000625010987278074 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000864955014549196 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000624526990577579 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000865689013153315 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000625425018370152 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000864878995344043 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000625386019237339 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000865727022755891 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000625569024123251 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000865650014020503 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000625308020971715 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000865111011080444 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000625450978986919 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000864650995936245 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000625098997261375 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000865036970935762 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000625637010671198 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000865266018081456 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000624937005341053 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000626012973953038 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000863653025589883 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000625839980784804 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000864267989527434 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000626116001512855 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000863805995322764 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000625587999820709 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000863809022121131 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000626707973424345 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000863038992974907 / GTC secondary mirror RY position
#   self._image)
# ...
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000640304002445191 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000835686980281025 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000640448997728527 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000835302984341979 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000641395978163928 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000834686972666532 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000641766004264355 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000835456012282521 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000641243997961283 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000834072008728981 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000641169026494026 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000642072991468012 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000833148020319641 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000642930972389877 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000832304998766631 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000642633007373661 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000832381017971784 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000641844002529979 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000832766992971301 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000831919023767114 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000642938015516847 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000831611978355795 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000831688987091184 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000642919971141964 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000643908977508545 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000831537006888539 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000643745996057987 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000830151024274528 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000643178995233029 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000829997006803751 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000644481973722577 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000643740990199149 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000643485982436687 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000828536984045058 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000644385989289731 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000828383024781942 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000644755025859922 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000827994022984058 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000644948973786086 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000827228010166436 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000644647981971502 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000827458978164941 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000644974003080279 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000826383009552956 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000645254971459508 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000826076022349298 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000646158005110919 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000825537019409239 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000645947991870344 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000826306000817567 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000646493979729712 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000645793974399567 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000824999995529652 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000646032975055277 / GTC secondary mirror RX position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000824921997264028 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RY    =-0.000824538001324981 / GTC secondary mirror RY position
#   self._image)
# /home/mert3269/Library/Python/2.7/lib/python/site-packages/pyfits/card.py:979: UserWarning: The following header keyword is invalid or follows an unrecognized non-standard convention:
# M2RX    =-0.000646947999484837 / GTC secondary mirror RX position
#   self._image)

# %% [markdown]
# ## Read in the wavelength solutions
#
# The spectra have been extracted using a subsection from the original CCD (also along the dispersion axis), this must be accounted for when calculating the wavelength table.

# %%
wls = load(join('results','wl_calibration.pkl'), 'r')
ccdsec = eval('['+pf.getval(sfiles_2[0],'ccdsec').split(',')[-1].replace(':',','))
pixels = arange(ccdsec[0], ccdsec[1]+1)

wl1 = wls['ccd1'].pixel_to_wl(pixels)
wl2 = wls['ccd2'].pixel_to_wl(pixels)
wl1.shape
# Out:
# (1990,)

# %% [markdown]
# ## Plot the spectra

# %%
fig,axs = subplots(2,1, sharey=True, sharex=True)
wls = [wl1,wl2]
sps = [normalise(spectra_1[0]),normalise(spectra_2[0])]
aws = zip(axs,wls,sps)
[ax.plot(wl, sp, c=cp[0], alpha=0.25, zorder=1) for ax,wl,sp in aws]
[[ax.fill(wl, f(wl)*sp, ec=cp[0], lw=1, fc='0.95', zorder=0) for f in pb_filters_nb] for ax,wl,sp in aws]
[[a.axvline(wlc, ls='--', alpha=0.5, zorder=2) for wlc in r_[wlc_na,wlc_k]] for a in axs]
setp(axs, xlim=(wl1[[0,-1]]), ylim=(0,1.6), yticks=[])
fig.tight_layout()
print sp.shape
print wl1.shape
# Out:
# (1990,)
# (1990,)

# %% [markdown]
# ## Create the spectrum mask
#
# Telluric absorption can cause significant increase of noise in the narrow-band light curves. Here we create masks that remove the cores of the telluric absorption lines from the spectra.

# %%
def create_mask(s, lims=None, elim=None, erosion_iterations=2, plot=True, figsize=(13,8), fs=12):
    x = arange(s.shape[0])
    if lims:
        tmask = (x < lims[0]) | (x > lims[1])
    else:
        tmask = ones(x.size, np.bool)
        
    p = poly1d(polyfit(x[tmask], s[tmask,:].mean(1), 4))
    
    lc_std = (s[tmask,:]/p(x[tmask])[:,newaxis]).std(0)
    smask  = binary_erosion(lc_std < elim, iterations=erosion_iterations, border_value=1)
    
    if plot:
        fig = figure(figsize=figsize)
        gs = GridSpec(2,2, width_ratios=(0.85,0.15), height_ratios=(0.6,0.4))
        axs = ae, ai, at = subplot(gs[0,0]), subplot(gs[1,0]), subplot(gs[1,1])
        ai.imshow(s, aspect='auto', interpolation='nearest', origin='lower')
       
        ae.plot(lc_std)
        ae.plot(0.035 + where(smask, lc_std, nan))
        ae.plot(where(smask, nan, -0.005), lw=3, c='k')   

        spec  = (s[tmask,:]/p(x[tmask])[:,newaxis]).mean(0)
        spec -= spec.min()
        spec /= spec.max()
        ae.plot(0.12+0.15*spec, alpha=0.5, c=cp[2])
        
        at.plot(s.mean(1), x, alpha=0.5)
        at.plot(p(x), x, 'k--', alpha=0.5)

        if lims is not None:
            ai.axhspan(*lims, ec='k', lw=2, fill=False, alpha=0.5)
            ai.axhspan(*lims, fc='w', ec='w', lw=1, fill=True, alpha=0.25)
            at.axhspan(*lims, ec='k', lw=2, fill=False, alpha=0.5)
            at.axhspan(*lims, fc='w', fill=True, alpha=0.25)

        if elim:
            ae.axhline(elim, ls='-', c=c_bo, alpha=0.25, zorder=-100)

        ae.text(0.01,0.94,'a', transform=ae.transAxes, size=fs)
        ai.text(0.97,0.88,'b', transform=ai.transAxes, size=fs)
        at.text(0.85,0.88,'c', transform=at.transAxes, size=fs)
            
        setp(ai, xlim=[0,s.shape[1]], ylim=x[[0,-1]], ylabel='Exposure', xlabel='Pixel')
        setp(ae, xlim=[0,s.shape[1]], xticks=[], ylim=(-0.015,0.28), ylabel='Normalized flux')
        setp(at, ylim=x[[0,-1]], yticks=[], xticks=[], xlabel='Relative flux')

        fig.tight_layout()
        sb.despine(ax=ae)
    
    return smask if not plot else smask,fig,axs

# %%
m1,f1,a1 = create_mask(spectra_1/median(spectra_1), elim=0.015, erosion_iterations=3)

# %%
m2,f2,a2 = create_mask(spectra_2/median(spectra_2), lims=(45,180), elim=0.0175, erosion_iterations=3)

# %% [markdown]
# ## Create the bad-point mask

# %%
bmsk = ones(spectra_1.shape[0], np.bool)
bmsk[[151,152]] = 0
bmsk[230:] = 0

# %% [markdown]
# ## Create the light curves
#
# The light curves are name as `lc_BB_N_MMMMMM` where `BB` is either `nb` for a narrow band or `bb` for the broad passband, `N` is 1 for the reference star and `2` for TrES-3, and `MMMMMM` is either `mask` or `nomask`.

# %%
lc_nb_1_nomask = array([[mean(f(wl1)*s) for f in pb_filters_nb] for s in spectra_1])
lc_nb_2_nomask = array([[mean(f(wl2)*s) for f in pb_filters_nb] for s in spectra_2])

# %%
lc_nb_1_masked = array([[nanmean(f(wl1)*where(m1,s,nan)) for f in pb_filters_nb] for s in spectra_1])
lc_nb_2_masked = array([[nanmean(f(wl2)*where(m2,s,nan)) for f in pb_filters_nb] for s in spectra_2])

# %%
lc_bb_1_nomask = array([mean(pb_filter_bb(wl1)*s) for s in spectra_1])
lc_bb_2_nomask = array([mean(pb_filter_bb(wl2)*s) for s in spectra_2])
lc_bb_1_masked = array([nanmean(pb_filter_bb(wl1)*where(m1,s,nan)) for s in spectra_1])
lc_bb_2_masked = array([nanmean(pb_filter_bb(wl2)*where(m2,s,nan)) for s in spectra_2])

# %%
lc_bb_nomask = normalise(lc_bb_2_nomask/lc_bb_1_nomask)
lc_bb_masked = normalise(lc_bb_2_masked/lc_bb_1_masked)
lc_nb_nomask = array([normalise(lc) for lc in (lc_nb_2_nomask/lc_nb_1_nomask).T]).T
lc_nb_masked = array([normalise(lc) for lc in (lc_nb_2_masked/lc_nb_1_masked).T]).T

# %%
fig,ax = subplots(1,1)
ax.plot(normalise(lc_bb_2_nomask/lc_bb_1_nomask))
ax.plot(0.015+normalise(lc_bb_2_masked/lc_bb_1_masked))
setp(ax, xlim=[0,lc_nb_2_nomask.shape[0]], ylim=[0.97,1.022])
fig.tight_layout()

# %%
fig,axs = subplots(4,4,figsize=(13,8), sharey=True, sharex=True)
for i,a in enumerate(axs.flat):
    lcr =  normalise(lc_nb_2_nomask[:,i]/lc_nb_1_nomask[:,i])
    lcm =  normalise(lc_nb_2_masked[:,i]/lc_nb_1_masked[:,i])
    a.plot(where(bmsk, lcr, nan), c=cp[0])
    a.plot(where(bmsk, nan, lcr), '.', c=cp[0], alpha=0.25)
    a.plot(where(bmsk, 0.012+lcm, nan), c=cp[1])
    a.plot(where(bmsk, nan, 0.012+lcm), '.', c=cp[1], alpha=0.25)
setp(axs, xlim=[0,lc_nb_2_nomask.shape[0]], ylim=[0.97,1.022])
fig.tight_layout()

# %% [markdown]
# ## Get the auxiliary parameters

# %%
time, airmass, humidity, pressure = [],[],[],[]

for fn in sfiles_1:
    f = pf.open(fn)
    time.append(f[0].header['date-obs'])
    airmass.append(f[0].header['airmass'])
    humidity.append(f[0].header['humidity'])
    pressure.append(f[0].header['pressure'])
    f.close()
mjd = Time(time).mjd

df_aux = pd.DataFrame(transpose([mjd,airmass,humidity,pressure,bmsk]), 
                  columns='mjd airmass humidity pressure bad_mask'.split())

# %%
df_filters = pd.DataFrame(transpose([f(wl2) for f in pb_filters_nb]), columns=pb_centers)

# %% [markdown]
# ## Write the light curves and the auxiliary data into a HDF5 file

# %%
bbargs = dict(columns=['white'], index=mjd)
nbargs = dict(columns=pb_centers, index=mjd)

with pd.HDFStore('results/light_curves.h5') as hdf:
    hdf.put('aux', df_aux, format='table', data_columns=True)
    hdf.put('filters', df_aux, format='table', data_columns=True)
    hdf.put('bad_exposures', pd.Series(bmsk), format='table')
    hdf.put('final/bb_nomask',     DF(lc_bb_nomask,   **bbargs), data_columns=True)
    hdf.put('final/bb_masked',     DF(lc_bb_masked,   **bbargs), data_columns=True)
    hdf.put('final/nb_nomask',     DF(lc_nb_nomask,   **nbargs), data_columns=True)
    hdf.put('target/bb_nomask',    DF(lc_bb_2_nomask, **bbargs), data_columns=True)
    hdf.put('target/bb_masked',    DF(lc_bb_2_masked, **bbargs), data_columns=True)
    hdf.put('target/nb_nomask',    DF(lc_nb_2_nomask, **nbargs), data_columns=True)
    hdf.put('target/nb_masked',    DF(lc_nb_2_masked, **nbargs), data_columns=True)
    hdf.put('reference/bb_nomask', DF(lc_bb_1_nomask, **bbargs), data_columns=True)
    hdf.put('reference/bb_masked', DF(lc_bb_1_masked, **bbargs), data_columns=True)
    hdf.put('reference/nb_nomask', DF(lc_nb_1_nomask, **nbargs), data_columns=True)
    hdf.put('reference/nb_masked', DF(lc_nb_1_nomask, **nbargs), data_columns=True)

# %% [markdown]
# ## Create the plots for the paper

# %%
with sb.plotting_context('paper', rc=rc_paper):
    m1,f1,a1 = create_mask(spectra_1/median(spectra_1), elim=0.015,
                           erosion_iterations=3, figsize=(AAPGW,AAOCW), fs=6.5)
    f1.savefig('plots/pub_smask_c.pdf')

# %%
with sb.plotting_context('paper', rc=rc_paper):
    m2,f2,a2 = create_mask(spectra_2/median(spectra_2), lims=(45,180), elim=0.0175, 
                           erosion_iterations=3, figsize=(AAPGW,AAOCW), fs=6.5)
    f2.savefig('plots/pub_smask_t.pdf')

# %%
with sb.plotting_context('paper', rc=rc_paper):
    with sb.axes_style('ticks'):
        time = array(df_aux.mjd) - floor(df_aux.mjd[0])
        fig,ax = subplots(1,1, figsize=(AAOCW,0.6*AAOCW))
        ax.plot(time, lc_bb_2_nomask/lc_bb_2_nomask[0], c=c_ob, lw=1)
        ax.plot(time, lc_bb_1_nomask/lc_bb_1_nomask[0] +0.015, c=c_bo, lw=1)
        setp(ax, xlim=time[[0,-1]], ylabel='Normalised flux', xlabel='MJD - {:5.0f}'.format(floor(df_aux.mjd[0])))
        sb.despine(fig)
        fig.tight_layout()
        fig.subplots_adjust(left=0.15, right=0.99, bottom=0.20, top=0.97)
        fig.savefig('plots/pub_lc_bb_raw.pdf')

# %%
with sb.plotting_context('paper', rc=rc_paper):
    fig,ax = subplots(1,1, figsize=(AAOCW,0.6*AAOCW))
    plot(time, normalise(lc_bb_2_nomask/lc_bb_1_nomask), c=c_ob)
    setp(ax, xlim=time[[0,-1]], ylim=(0.97,1.01), ylabel='Normalised flux', 
         xlabel='MJD - {:5.0f}'.format(floor(df_aux.mjd[0])))
    fig.tight_layout()
    sb.despine(fig)
    fig.savefig('plots/pub_lc_bb_rel.pdf')

# %%
df = 81000.
sc,st = spectra_1[0]/df, spectra_2[0]/df

with sb.plotting_context('paper', rc=rc_paper):
    with sb.axes_style('ticks'):
        fig,ax = subplots(1,1,figsize=(AAOCW,0.6*AAOCW))
        [ax.plot(wl1, f(wl1)*sc, c=c_bo, lw=1, alpha=0.1, zorder=-100) for f in pb_filters_nb]
        ax.plot(wl1, sc, c=c_bo, lw=1, alpha=0.15, zorder=100)
        ax.plot(wl1, where(m1, sc, nan), c=c_bo, lw=1, alpha=1, zorder=100)
        ax.plot(wl2, st, c=c_ob, lw=1, alpha=0.15, zorder=101)
        ax.plot(wl2, where(m2, st, nan), c=c_ob, lw=1, alpha=1, zorder=101)
        [ax.text(pbc, 0.06, i+1, ha='center', size=5, bbox=dict(facecolor='white', edgecolor='white')) 
         for i,pbc in enumerate(pb_centers)]
        [ax.axvline(wlc, c=cp[0], alpha=0.25, ls=':', lw=1, zorder=-100) for wlc in r_[wlc_k,wlc_na]]
        sb.despine(fig)
        setp(ax, xlabel='Wavelength [nm]', xlim=(500,950), ylim=(0,1.8), ylabel='Relative flux')
        fig.subplots_adjust(left=0.13, right=0.96, bottom=0.20, top=0.97)
        fig.savefig('plots/pub_spectra.pdf')

# %% [markdown]
# ---
# <center> &copy; 2015 <a href="mailto:hannu.parviainen@physics.ox.ac.uk">Hannu Parviainen</a></center>
